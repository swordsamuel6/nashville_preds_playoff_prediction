# %% [markdown]
# https://www.quanthockey.com/nhl/team-game-logs/nashville-predators-2022-23-nhl-game-log.html

# %%
import pandas as pd
import datetime as dt

# %%
data = pd.read_csv('data_raw/QuantHockey.csv')

# %%
data.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
data.columns = data.iloc[0]

# %%
data.drop(0, inplace = True)

# %%
data['Date']= pd.to_datetime(data['Date'])

# %%
half_of_games = data[data['Date'] <= '2023-01-11']

# %%
len(half_of_games)
# Out:
# 40

# %%
half_of_games.rename({'Loc.': 'Loc'}, axis = 1, inplace = True)
# Out:
# C:\Users\csky2\AppData\Local\Temp\ipykernel_20744\603097154.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   half_of_games.rename({'Loc.': 'Loc'}, axis = 1, inplace = True)

# %%
half_of_games.Result.unique()
# Out:
# array(['Loss', 'Win', 'OT Loss', 'OT Win', 'SO Win', 'SO Loss'],
#       dtype=object)

# %%
half_of_games[['Loc', 'Result']]
# Out:
# 0    Loc   Result
# 18  Away     Loss
# 19  Away      Win
# 20  Away      Win
# 21  Away      Win
# 22  Home      Win
# 23  Away  OT Loss
# 24  Away      Win
# 25  Home     Loss
# 26  Home  OT Loss
# 27  Away      Win
# 28  Home   OT Win
# 29  Away     Loss
# 30  Away  OT Loss
# 31  Home     Loss
# 32  Away  OT Loss
# 33  Home     Loss
# 34  Away     Loss
# 35  Away      Win
# 36  Away   OT Win
# 37  Home   OT Win
# 38  Away     Loss
# 39  Home   SO Win
# 40  Home  OT Loss
# 41  Home      Win
# 42  Home      Win
# 43  Home      Win
# 44  Away     Loss
# 45  Away     Loss
# 46  Away   SO Win
# 47  Away      Win
# 48  Away     Loss
# 49  Home     Loss
# 50  Home      Win
# 51  Home     Loss
# 52  Away     Loss
# 53  Home  SO Loss
# 54  Away     Loss
# 55  Home     Loss
# 56  Away      Win
# 57  Home      Win

# %%
#away wins
away_wins = half_of_games[(half_of_games['Loc'] == 'Away') & ((half_of_games['Result'] == 'Win') | (half_of_games['Result'] == 'OT Win') | (half_of_games['Result'] == 'SO Win'))]
len(away_wins)
# Out:
# 10

# %%
# home wins
home_wins = half_of_games[(half_of_games['Loc'] == 'Home') & ((half_of_games['Result'] == 'Win') | (half_of_games['Result'] == 'OT Win') | (half_of_games['Result'] == 'SO Win'))]
len(home_wins)
# Out:
# 9

# %%
# home losses
home_losses = half_of_games[(half_of_games['Loc'] == 'Home') & ((half_of_games['Result'] == 'Loss') | (half_of_games['Result'] == 'OT Loss') | (half_of_games['Result'] == 'SO Loss'))]
len(home_losses)
# Out:
# 9

# %%
#  away losses
away_losses = half_of_games[(half_of_games['Loc'] == 'Away') & ((half_of_games['Result'] == 'Loss') | (half_of_games['Result'] == 'OT Loss') | (half_of_games['Result'] == 'SO Loss'))]
len(away_losses)
# Out:
# 12

# %%
# Goals scored
sum(half_of_games.GF.apply(lambda x: int(x)))
# Out:
# 112

# %%
# Goals against
sum(half_of_games.GA.apply(lambda x: int(x)))
# Out:
# 117

# %%
# avg goals scored per game
half_of_games.GF.apply(lambda x: int(x)).mean()
# Out:
# 2.8

# %%
# avg goals against per game
half_of_games.GA.apply(lambda x: int(x)).mean()
# Out:
# 2.925

# %%
half_of_games
# Out:
# 0        Date               Opponent   Loc   Result GF GA  GD     PDO   PDO-A  \
# 18 2023-01-11    Toronto Maple Leafs  Away     Loss  1  2  -1   97.3%  102.7%
# 19 2023-01-09        Ottawa Senators  Away      Win  3  0   3  108.3%   91.7%
# 20 2023-01-06    Washington Capitals  Away      Win  3  2   1  108.0%   92.0%
# 21 2023-01-05    Carolina Hurricanes  Away      Win  5  3   2  115.5%   87.8%
# 22 2023-01-03     Montreal Canadiens  Home      Win  6  3   3  106.5%   93.5%
